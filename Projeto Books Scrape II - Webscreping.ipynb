# %%
6.0.1 1. Coletar os seguintes dados da página: https://books.toscrape.com
        
• Catálogo:
                    Nome do livro    Preço     Avaliação         estoque
– Classics
– Science Fiction
– Humor
– Business

• Coletar os seguintes dados de cada livro:
    
– Nome do livro
– Preço em libras
– Avaliação dos consumidores
– Disponível em estoque

6.0.2 Entregável:
- Faça um plano escrito para cada uma das perguntas de negócio, contendo:
    
- Saída: A simulação da tabela e gráfico final.
    
- Processo: A sequência de passos organizada pela lógica de execução
    
- Entrada: O link para as fontes de dados.
    
- Uma csv com todas as informação de todos os catálogos.

### Faça um plano escrito para cada uma das perguntas de negócio, contendo:

- Saída: A simulação da tabela e gráfico final.
    
        upc      |   Catálogo   |    Nome do livro     | Preço em libras | Avaliação (0-5) | Em estoque 
a897fe39b1053632 |              | A Light in the Attic |     L 51.77     |       3         |    sim

https://docs.google.com/spreadsheets/d/1yIf9-P0cvWEl5o7X1rHxJAknFQNvR8PRnKnp4JzIOYE/edit#gid=0
    
    
### Processo: A sequência de passos organizada pela lógica de execução

- Criar novo dataframe

- fazer Scraping dos generos e adiciona-los neste novo DF
        upc      |   Catálogo   |    Nome do livro     | Preço em libras | Avaliação (0-5) | Em estoque 
a897fe39b1053632 |              | A Light in the Attic |     L 51.77     |       3         |    sim

- Fazer um novo DF para cada Genero e um geral com todas as informações reunidas

- criar o arquivo csv com todos os catalogos solicitados

### Entrada: O link para as fontes de dados.

https://books.toscrape.com/index.html

    
### Um csv com todas as informação de todos os catálogos.

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# Escolhendo site para Screaping

url = 'https://books.toscrape.com/catalogue/category/books/classics_6/index.html'

# Colocando url padrão para o site não perceber o Scrap

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

# Preparando
           
page = requests.get( url, headers=headers )

soup = BeautifulSoup( page.text, 'html.parser')

# Começando a seleção

titulo = soup.find_all('article', class_= 'product_pod')

# Titulo suporte para poder pegar a variável 'UPC'

titulo_suporte = [(i.a.prettify().replace("/",",").split(',')[3]) for i in titulo]

df_titulo_suporte = pd.DataFrame(titulo_suporte,columns=['titulo_suporte'])

# Titulo livro

titulo_livro = [p.h3.a.string for p in titulo]

df_titulo_livro = pd.DataFrame(titulo_classic, columns=['titulo_livro'])

# Classificação

ranking = [i.p.get('class')[1] for i in titulo]

df_ranking = pd.DataFrame(ranking, columns=['ranking'])

# Preço em libras

price = soup.find_all('div', class_= 'product_price')

price_libras = [(j.p.next_element).replace("Â","") for j in price]

df_price_libras = pd.DataFrame(price_libras, columns=['price_libras'])

# Estoque

stock = [(j.i.next.replace("\n","").replace(" ","")) for j in price]

df_stock = pd.DataFrame(stock, columns=['stock'])

# novo DF

df_books_classics = pd.concat([df_stock, df_price_libras, df_ranking, df_titulo_livro],axis=1)

df_books_classics['genero']='classics'

df_books_classics
# Out:
#       stock price_libras ranking                      titulo_livro    genero
# 0   Instock       £15.08    Four                 The Secret Garden  classics
# 1   Instock       £28.58     One                 The Metamorphosis  classics
# 2   Instock       £50.26     Two            The Pilgrim's Progress  classics
# 3   Instock       £14.82     Two              The Hound of the ...  classics
# 4   Instock       £28.07    Four    Little Women (Little Women ...  classics
# 5   Instock       £32.49   Three                Gone with the Wind  classics
# 6   Instock       £58.63   Three                           Candide  classics
# 7   Instock       £57.22   Three                       Animal Farm  classics
# 8   Instock       £17.73   Three                 Wuthering Heights  classics
# 9   Instock       £29.70     Two         The Picture of Dorian ...  classics
# 10  Instock       £26.78    Four      The Complete Stories and ...  classics
# ...

# %%
df_books_classics.to_csv('F:\\Repos_DS\\Python_DS_ao_DEV\\webscreping_df_books_classics.csv', index = False)

# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup

# Escolhendo site para Screaping

url = 'https://books.toscrape.com/catalogue/category/books/science-fiction_16/index.html'

# Colocando url padrão para o site não perceber o Scrap

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

# Preparando
           
page = requests.get( url, headers=headers )

soup = BeautifulSoup( page.text, 'html.parser')

# Começando a seleção

titulo = soup.find_all('article', class_= 'product_pod')

# Titulo livro

titulo_livro = [p.h3.a.string for p in titulo]


df_titulo_livro = pd.DataFrame(titulo_science_fiction, columns=['titulo_livro'])

# Classificação

ranking = [i.p.get('class')[1] for i in titulo]

df_ranking = pd.DataFrame(ranking, columns=['ranking'])


# Preço em libras

price = soup.find_all('div', class_= 'product_price')

price_libras = [(j.p.next_element).replace("Â","") for j in price]

df_price_libras = pd.DataFrame(price_libras, columns=['price_libras'])

# Estoque

stock = [(j.i.next.replace("\n","").replace(" ","")) for j in price]

df_stock = pd.DataFrame(stock, columns=['stock'])


# novo DF

df_books_science_fiction = pd.concat([df_stock, df_price_libras, df_ranking, df_titulo_livro],axis=1)

df_books_science_fiction['genero']='science-fiction'

df_books_science_fiction
# Out:
#       stock price_libras ranking  \
# 0   Instock       £37.59     One
# 1   Instock       £35.67    Five
# 2   Instock       £43.30    Four
# 3   Instock       £10.65     One
# 4   Instock       £26.12     Two
# 5   Instock       £48.74     One
# 6   Instock       £21.36    Four
# 7   Instock       £32.42     One
# 8   Instock       £10.92     One
# 9   Instock       £19.07    Four
# 10  Instock       £33.26     Two
# 11  Instock       £54.86     One
# 12  Instock       £51.48     One
# 13  Instock       £44.18     Two
# 14  Instock       £36.26     Two
# 15  Instock       £34.96    Four
#
#                                       titulo_livro           genero
# 0                  Mesaerion: The Best Science ...  science-fiction
# 1                                             Join  science-fiction
# 2             William Shakespeare's Star Wars: ...  science-fiction
# 3                                      The Project  science-fiction
# ...

# %%
df_books_science_fiction.to_csv('F:\\Repos_DS\\Python_DS_ao_DEV\\webscreping_df_books_science_fiction.csv', index = False)

# %%
df_books_final = pd.merge(df_books_science_fiction,df_books_classics, how='outer')
df_books_final
# Out:
#       stock price_libras ranking  \
# 0   Instock       £37.59     One
# 1   Instock       £35.67    Five
# 2   Instock       £43.30    Four
# 3   Instock       £10.65     One
# 4   Instock       £26.12     Two
# 5   Instock       £48.74     One
# 6   Instock       £21.36    Four
# 7   Instock       £32.42     One
# 8   Instock       £10.92     One
# 9   Instock       £19.07    Four
# 10  Instock       £33.26     Two
# 11  Instock       £54.86     One
# 12  Instock       £51.48     One
# 13  Instock       £44.18     Two
# 14  Instock       £36.26     Two
# 15  Instock       £34.96    Four
# 16  Instock       £15.08    Four
# 17  Instock       £28.58     One
# 18  Instock       £50.26     Two
# 19  Instock       £14.82     Two
# 20  Instock       £28.07    Four
# 21  Instock       £32.49   Three
# 22  Instock       £58.63   Three
# 23  Instock       £57.22   Three
# 24  Instock       £17.73   Three
# 25  Instock       £29.70     Two
# 26  Instock       £26.78    Four
# ...

# %%
df_books_final.to_csv('F:\\Repos_DS\\Python_DS_ao_DEV\\webscreping_df_books_final.csv', index = False)

# %%
# Escolhendo site para Screaping

url = 'https://books.toscrape.com/catalogue/category/books/humor_30/index.html'

# Colocando url padrão para o site não perceber o Scrap

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

# Preparando
           
page = requests.get( url, headers=headers )

soup = BeautifulSoup( page.text, 'html.parser')

# Começando a seleção

titulo = soup.find_all('article', class_= 'product_pod')

# Titulo livro

titulo_livro = [p.h3.a.string for p in titulo]


df_titulo_livro = pd.DataFrame(titulo_livro, columns=['titulo_livro'])

# Classificação

ranking = [i.p.get('class')[1] for i in titulo]

df_ranking = pd.DataFrame(ranking, columns=['ranking'])


# Preço em libras

price = soup.find_all('div', class_= 'product_price')

price_libras = [(j.p.next_element).replace("Â","") for j in price]

df_price_libras = pd.DataFrame(price_libras, columns=['price_libras'])

# Estoque

stock = [(j.i.next.replace("\n","").replace(" ","")) for j in price]

df_stock = pd.DataFrame(stock, columns=['stock'])


# novo DF

df_books_humor = pd.concat([df_stock, df_price_libras, df_ranking, df_titulo_livro],axis=1)

df_books_humor['genero']='humor'

df_books_humor
# Out:
#      stock price_libras ranking                     titulo_livro genero
# 0  Instock       £44.07     One         The Long Haul (Diary ...  humor
# 1  Instock       £11.83    Five         Old School (Diary of ...  humor
# 2  Instock       £25.98    Four              I Know What I'm ...  humor
# 3  Instock       £14.75    Five        Hyperbole and a Half: ...  humor
# 4  Instock       £43.68   Three         Dress Your Family in ...  humor
# 5  Instock       £25.55     One  Toddlers Are A**holes: It's ...  humor
# 6  Instock       £30.89    Five        When You Are Engulfed ...  humor
# 7  Instock       £31.69   Three                            Naked  humor
# 8  Instock       £55.50    Five   Lamb: The Gospel According ...  humor
# 9  Instock       £51.07     Two                  Holidays on Ice  humor

# %%
df_books_final2 = pd.merge(df_books_final,df_books_humor, how='outer')
df_books_final2
# Out:
#       stock price_libras ranking  \
# 0   Instock       £37.59     One
# 1   Instock       £35.67    Five
# 2   Instock       £43.30    Four
# 3   Instock       £10.65     One
# 4   Instock       £26.12     Two
# 5   Instock       £48.74     One
# 6   Instock       £21.36    Four
# 7   Instock       £32.42     One
# 8   Instock       £10.92     One
# 9   Instock       £19.07    Four
# 10  Instock       £33.26     Two
# 11  Instock       £54.86     One
# 12  Instock       £51.48     One
# 13  Instock       £44.18     Two
# 14  Instock       £36.26     Two
# 15  Instock       £34.96    Four
# 16  Instock       £15.08    Four
# 17  Instock       £28.58     One
# 18  Instock       £50.26     Two
# 19  Instock       £14.82     Two
# 20  Instock       £28.07    Four
# 21  Instock       £32.49   Three
# 22  Instock       £58.63   Three
# 23  Instock       £57.22   Three
# 24  Instock       £17.73   Three
# 25  Instock       £29.70     Two
# 26  Instock       £26.78    Four
# ...

# %%
# Escolhendo site para Screaping

url = 'https://books.toscrape.com/catalogue/category/books/business_35/index.html'

# Colocando url padrão para o site não perceber o Scrap

headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

# Preparando
           
page = requests.get( url, headers=headers )

soup = BeautifulSoup( page.text, 'html.parser')

# Começando a seleção

titulo = soup.find_all('article', class_= 'product_pod')

# Titulo livro

titulo_livro = [p.h3.a.string for p in titulo]


df_titulo_livro = pd.DataFrame(titulo_livro, columns=['titulo_livro'])

# Classificação

ranking = [i.p.get('class')[1] for i in titulo]

df_ranking = pd.DataFrame(ranking, columns=['ranking'])


# Preço em libras

price = soup.find_all('div', class_= 'product_price')

price_libras = [(j.p.next_element).replace("Â","") for j in price]

df_price_libras = pd.DataFrame(price_libras, columns=['price_libras'])

# Estoque

stock = [(j.i.next.replace("\n","").replace(" ","")) for j in price]

df_stock = pd.DataFrame(stock, columns=['stock'])


# novo DF

df_books_busines = pd.concat([df_stock, df_price_libras, df_ranking, df_titulo_livro],axis=1)

df_books_busines['genero']='busines'

df_books_busines
# Out:
#       stock price_libras ranking                    titulo_livro   genero
# 0   Instock       £33.34    Four    The Dirty Little Secrets ...  busines
# 1   Instock       £12.61    Five          The Third Wave: An ...  busines
# 2   Instock       £27.55   Three  The 10% Entrepreneur: Live ...  busines
# 3   Instock       £23.99     Two          Shoe Dog: A Memoir ...  busines
# 4   Instock       £38.85    Five          Made to Stick: Why ...  busines
# 5   Instock       £43.14     One     Quench Your Own Thirst: ...  busines
# 6   Instock       £21.00   Three          The Art of Startup ...  busines
# 7   Instock       £21.59    Five          Born for This: How ...  busines
# 8   Instock       £36.91     One   The E-Myth Revisited: Why ...  busines
# 9   Instock       £51.74     One              Rich Dad, Poor Dad  busines
# 10  Instock       £33.92   Three       The Lean Startup: How ...  busines
# 11  Instock       £44.88     Two                          Rework  busines

# %%
df_books_to_scrape_final = pd.merge(df_books_final2,df_books_busines, how='outer')
df_books_to_scrape_final
# Out:
#       stock price_libras ranking  \
# 0   Instock       £37.59     One
# 1   Instock       £35.67    Five
# 2   Instock       £43.30    Four
# 3   Instock       £10.65     One
# 4   Instock       £26.12     Two
# 5   Instock       £48.74     One
# 6   Instock       £21.36    Four
# 7   Instock       £32.42     One
# 8   Instock       £10.92     One
# 9   Instock       £19.07    Four
# 10  Instock       £33.26     Two
# 11  Instock       £54.86     One
# 12  Instock       £51.48     One
# 13  Instock       £44.18     Two
# 14  Instock       £36.26     Two
# 15  Instock       £34.96    Four
# 16  Instock       £15.08    Four
# 17  Instock       £28.58     One
# 18  Instock       £50.26     Two
# 19  Instock       £14.82     Two
# 20  Instock       £28.07    Four
# 21  Instock       £32.49   Three
# 22  Instock       £58.63   Three
# 23  Instock       £57.22   Three
# 24  Instock       £17.73   Three
# 25  Instock       £29.70     Two
# 26  Instock       £26.78    Four
# ...

# %%
df_books_to_scrape_final.to_csv('F:\\Repos_DS\\Python_DS_ao_DEV\\webscreping_df_books_to_scrape_final.csv', index = False)
